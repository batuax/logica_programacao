# %% [markdown]
# # Calculadora

# %%
# Função para somar
def somar(x, y):
    return x + y

# Função para subtrair
def subtrair(x, y):
    return x - y

# Função para multiplicar
def multiplicar(x, y):
    return x * y

# Função para dividir
def dividir(x, y):
    if y == 0:
        return "Erro! Não é possível dividir por zero."
    else:
        return x / y

# Função para potência
def potencia(x, y):
    return x ** y

# Função para calcular a raiz quadrada
import math
def raiz_quadrada(x):
    if x < 0:
        return "Erro! Não é possível calcular a raiz quadrada de um número negativo."
    else:
        return math.sqrt(x)

# Função para exibir o menu de operações
def menu():
    print("\nEscolha a operação que deseja realizar:")
    print("1. Soma")
    print("2. Subtração")
    print("3. Multiplicação")
    print("4. Divisão")
    print("5. Potência")
    print("6. Raiz Quadrada")
    print("7. Sair")

# Função principal que controla o fluxo do programa
def calculadora():
    while True:
        menu()

        # Leitura da escolha do usuário
        escolha = input("Digite sua escolha (1/2/3/4/5/6/7): ")

        # Se o usuário escolheu sair
        if escolha == '7':
            print("Obrigado por usar a calculadora! Até logo!")
            break

        #Uma operação que precise de dois números
        if escolha in ('1', '2', '3', '4', '5'):
            num1 = float(input("\nDigite o primeiro número: "))
            num2 = float(input("Digite o segundo número: "))

            if escolha == '1':
                print(f"\n{num1} + {num2} = {somar(num1, num2)}")
            elif escolha == '2':
                print(f"\n{num1} - {num2} = {subtrair(num1, num2)}")
            elif escolha == '3':
                print(f"\n{num1} * {num2} = {multiplicar(num1, num2)}")
            elif escolha == '4':
                print(f"\n{num1} / {num2} = {dividir(num1, num2)}")
            elif escolha == '5':
                print(f"\n{num1} ^ {num2} = {potencia(num1, num2)}")

        # Caso o usuário escolha calcular a raiz quadrada
        elif escolha == '6':
            num = float(input("\nDigite o número para calcular a raiz quadrada: "))
            print(f"\nA raiz quadrada de {num} é {raiz_quadrada(num)}")

        else:
            print("Opção inválida! Tente novamente.")

# Executar a calculadora
calculadora()
# Out:
# Escolha a operação que deseja realizar:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Potência
# 6. Raiz Quadrada
# 7. Sair
# Digite sua escolha (1/2/3/4/5/6/7): 2
#
# Digite o primeiro número: 3
# Digite o segundo número: 4
#
# 3.0 - 4.0 = -1.0
#
# Escolha a operação que deseja realizar:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Potência
# 6. Raiz Quadrada
# 7. Sair
# Digite sua escolha (1/2/3/4/5/6/7): 2
#
# Digite o primeiro número: 5555
# Digite o segundo número: 1
#
# 5555.0 - 1.0 = 5554.0
#
# Escolha a operação que deseja realizar:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Potência
# 6. Raiz Quadrada
# 7. Sair
