# %% [markdown]
# #Lista, tuplas e dicionários

# %%
# Lista
lista = [1, 2, 3, 4, 5]

# %%
# Tupla
tupla = (1, 2, 3, 4, 5)

# %%
# Dicionário
dicionario = {'num1': 1, 'num2': 2}

# %% [markdown]
# **Listas**

# %%
lista = [5, 'Jorge', 8.9]

# %%
type(lista)
# Out:
# list

# %%
lista.append("Brenda") # Adicionar um elemento na lista

# %%
print(lista)
print(lista[1])
# Out:
# [5, 'Jorge', 8.9]
# Jorge

# %% [markdown]
# **Tupola**

# %%
tupla = (5, 'Jorge', 8.9)

# %%
type(tupla)
# Out:
# tuple

# %%
tupla.append("Brenda")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-690840269.py in <cell line: 0>()
# ----> 1 tupla.append("Brenda")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
print(tupla)
# Out:
# (5, 'Jorge', 8.9)

# %% [markdown]
# **Dicionário**

# %%
dicionario = {'nome':'Jorge','cidade':'Salvador'}

# %%
type(dicionario)
# Out:
# dict

# %%
print(dicionario)
# Out:
# {'nome': 'Jorge', 'cidade': 'Salvador'}

# %%
print(dicionario['nome'])
# Out:
# Jorge

# %%
dicionario['ultimo_nome'] = 'Costa'

# %%
print(dicionario)
# Out:
# {'nome': 'Jorge', 'cidade': 'Salvador', 'ultimo_nome': 'Costa'}
